# %%
import pylangacq as pla
from os import chdir as cd
#pathin = '/Users/ethan/Documents/GitHub/CLA_2019/Coding/Friday Exercises/Data/NewmanRatner/24/'
pathin = '/Users/ethan/Documents/GitHub/CLA_2019/Coding/Friday Exercises/Data/Brown/Eve'

# %%
cd(pathin)
n = pla.read_chat('eve01.cha')

# %%
#dir(n)

# %%
#s = n.tagged_sents()
#print(s)

# %%
age = (sorted(n.age().values()))
print(age)
# Out:
# [(1, 6, 0)]

# %%
#convert age to months
age_years = age[0][0]
age_months = age[0][1]
age_months = age_months + age_years*12
print(age_months)
# Out:
# 18

# %%
#print(n.words())
w = n.tagged_words()
print(w)
# Out:
# [('more', 'QN', 'more', (1, 2, 'QUANT')), ('cookie', 'N', 'cookie', (2, 0, 'INCROOT')), ('.', '.', '', (3, 2, 'PUNCT')), ('you', 'PRO:PER', 'you', (1, 2, 'SUBJ')), ('0v', '0V', 'v', (2, 0, 'ROOT')), ('more', 'QN', 'more', (3, 4, 'QUANT')), ('cookies', 'N', 'cookie-PL', (4, 2, 'OBJ')), ('?', '?', '', (5, 2, 'PUNCT')), ('how_about', 'ADV:INT', 'how_about', (1, 3, 'LINK')), ('another', 'QN', 'another', (2, 3, 'QUANT')), ('grahamcracker', 'N', '+n|graham+n|cracker', (3, 0, 'INCROOT')), ('?', '?', '', (4, 3, 'PUNCT')), ('would', 'MOD', 'will&COND', (1, 3, 'AUX')), ('that', 'PRO:REL', 'that', (2, 3, 'LINK')), ('do', 'V', 'do', (3, 0, 'ROOT')), ('just', 'ADV', 'just', (4, 3, 'JCT')), ('as_well', 'ADV', 'as_well', (5, 3, 'JCT')), ('?', '?', '', (6, 3, 'PUNCT')), ('here', 'ADV', 'here', (1, 0, 'INCROOT')), ('.', '.', '', (2, 1, 'PUNCT')), ('here', 'ADV', 'here', (1, 3, 'JCT')), ('you', 'PRO:PER', 'you', (2, 3, 'SUBJ')), ('go', 'V', 'go', (3, 0, 'ROOT')), ('.', '.', '', (4, 3, 'PUNCT')), ('more', 'QN', 'more', (1, 2, 'QUANT')), ('cookie', 'N', 'cookie', (2, 0, 'INCROOT')), ('.', '.', '', (3, 2, 'PUNCT')), ('you', 'PRO:PER', 'you', (1, 2, 'SUBJ')), ('have', 'V', 'have', (2, 0, 'ROOT')), ('another', 'QN', 'another', (3, 4, 'QUANT')), ('cookie', 'N', 'cookie', (4, 2, 'OBJ')), ('right', 'ADV', 'right', (5, 2, 'JCT')), ('on', 'PREP', 'on', (6, 2, 'JCT')), ('the', 'DET:ART', 'the', (7, 8, 'DET')), ('table', 'N', 'table', (8, 6, 'POBJ')), ('.', '.', '', (9, 2, 'PUNCT')), ('more', 'QN', 'more', (1, 2, 'QUANT')), ('juice', 'N', 'juice', (2, 0, 'INCROOT')), ('?', '?', '', (3, 2, 'PUNCT')), ('more', 'QN', 'more', (1, 2, 'QUANT')), ('juice', 'N', 'juice', (2, 0, 'INCROOT')), ('?', '?', '', (3, 2, 'PUNCT')), ('would', 'MOD', 'will&COND', (1, 3, 'AUX')), ('you', 'PRO:PER', 'you', (2, 3, 'SUBJ')), ('like', 'V', 'like', (3, 0, 'ROOT')), ('more', 'QN', 'more', (4, 5, 'QUANT')), ('grape', 'N', 'grape', (5, 6, 'MOD')), ('juice', 'N', 'juice', (6, 3, 'OBJ')), ('?', '?', '', (7, 3, 'PUNCT')), ("where's", 'ADV:INT', 'where', (1, 2, 'LINK')), ('CLITIC', 'COP', 'be&3S', (2, 0, 'ROOT')), ('your', 'DET:POSS', 'your', (3, 4, 'MOD')), ('cup', 'N', 'cup', (4, 2, 'PRED')), ('?', '?', '', (5, 2, 'PUNCT')), ('oh', 'CO', 'oh', (1, 0, 'BEG')), ('‡', 'BEG', 'beg', (2, 1, 'BEGP')), ('I', 'PRO:SUB', 'I', (3, 4, 'SUBJ')), ('took', 'V', 'take&PAST', (4, 0, 'ROOT')), ('it', 'PRO:PER', 'it', (5, 4, 'OBJ')), ('.', '.', '', (6, 4, 'PUNCT')), ('Fraser', 'N:PROP', 'Fraser', (1, 0, 'INCROOT')), ('.', '.', '', (2, 1, 'PUNCT')), ('I', 'PRO:SUB', 'I', (1, 2, 'SUBJ')), ('think', 'V', 'think', (2, 0, 'ROOT')), ('that', 'PRO:DEM', 'that', (3, 4, 'SUBJ')), ('was', 'COP', 'be&PAST&13S', (4, 2, 'COMP')), ('Fraser', 'N:PROP', 'Fraser', (5, 4, 'PRED')), ('.', '.', '', (6, 2, 'PUNCT')), ("I'm", 'PRO:SUB', 'I', (1, 2, 'SUBJ')), ('CLITIC', 'COP', 'be&1S', (2, 0, 'ROOT')), ('not', 'NEG', 'not', (3, 2, 'NEG')), ('sure', 'ADJ', 'sure', (4, 2, 'PRED')), ('.', '.', '', (5, 2, 'PUNCT')), ('Fraser', 'N:PROP', 'Fraser', (1, 0, 'INCROOT')), ('.', '.', '', (2, 1, 'PUNCT')), ('what', 'PRO:INT', 'what', (1, 0, 'INCROOT')), ('?', '?', '', (2, 1, 'PUNCT')), ('are', 'COP', 'be&PRES', (1, 0, 'ROOT')), ('you', 'PRO:PER', 'you', (2, 1, 'OBJ')), ('saying', 'PART', 'say-PRESP', (3, 2, 'XJCT')), ('Fraser', 'N:PROP', 'Fraser', (4, 3, 'OBJ')), ('?', '?', '', (5, 1, 'PUNCT')), ('Mr', 'N:PROP', 'Mr', (1, 2, 'SUBJ')), ('Fraser', 'N:PROP', 'Fraser', (2, 0, 'INCROOT')), ('?', '?', '', (3, 2, 'PUNCT')), ('Fraser', 'N:PROP', 'Fraser', (1, 0, 'INCROOT')), ('.', '.', '', (2, 1, 'PUNCT')), ('yes', 'CO', 'yes', (1, 0, 'BEG')), ('‡', 'BEG', 'beg', (2, 1, 'BEGP')), ("that's", 'PRO:DEM', 'that', (3, 4, 'SUBJ')), ('CLITIC', 'COP', 'be&3S', (4, 0, 'ROOT')), ('much', 'ADV', 'much', (5, 6, 'JCT')), ('better', 'ADJ', 'good&CP', (6, 4, 'PRED')), ('.', '.', '', (7, 4, 'PUNCT')), ('Fraser', 'N:PROP', 'Fraser', (1, 0, 'INCROOT')), ('.', '.', '', (2, 1, 'PUNCT')), ('Mr', 'N:PROP', 'Mr', (1, 2, 'SUBJ')), ('Fraser', 'N:PROP', 'Fraser', (2, 0,  ...

# %%
words = n.words()
print(words)
with open('eve01_words.txt', 'a+') as newfile:
    newfile.write()
newfile.close()
# Out:
# ['more', 'cookie', '.', 'you', '0v', 'more', 'cookies', '?', 'how_about', 'another', 'grahamcracker', '?', 'would', 'that', 'do', 'just', 'as_well', '?', 'here', '.', 'here', 'you', 'go', '.', 'more', 'cookie', '.', 'you', 'have', 'another', 'cookie', 'right', 'on', 'the', 'table', '.', 'more', 'juice', '?', 'more', 'juice', '?', 'would', 'you', 'like', 'more', 'grape', 'juice', '?', "where's", 'your', 'cup', '?', 'oh', '‡', 'I', 'took', 'it', '.', 'Fraser', '.', 'I', 'think', 'that', 'was', 'Fraser', '.', "I'm", 'not', 'sure', '.', 'Fraser', '.', 'what', '?', 'are', 'you', 'saying', 'Fraser', '?', 'Mr', 'Fraser', '?', 'Fraser', '.', 'yes', '‡', "that's", 'much', 'better', '.', 'Fraser', '.', 'Mr', 'Fraser', '?', 'yeah', '.', 'that', '?', 'what', 'is', 'that', '?', 'huh', '?', 'what', 'is', 'that', '?', 'a', 'fly', '.', 'yes', '‡', 'a', 'fly', '.', 'why', "don't", 'you', 'go', 'in', 'the', 'room', 'and', 'kill', 'a', 'fly', '?', 'you', 'go', 'in', 'the', 'room', 'and', 'kill', 'a', 'fly', '.', 'fly', '.', 'yes', '‡', 'you', 'get', 'a', 'fly', '.', 'you', 'get', 'one', '.', 'are', 'you', 'finished', 'with', 'your', 'juice', '?', 'Mommy', 'telephone', '.', 'well', '‡', 'go', 'and', 'get', 'your', 'telephone', '.', 'yes', '‡', 'he', 'gave', 'you', 'your', 'telephone', '.', 'who', 'are', 'you', 'calling', '„', 'Eve', '?', 'my', 'telephone', '.', 'who', '?', '.', "what's", 'that', "you're", 'doing', '?', 'Mommy', '.', 'Eve', '‡', 'why', "don't", 'you', 'call', 'Grandma', '?', 'call', 'Grandma', 'and', 'talk', '...', 'no', '.', 'oh', '‡', 'you', "don't", 'wanna', 'talk', 'to', 'Grandma', '.', 'alright', '.', 'alright', '.', 'I', 'just', 'thought', 'she', 'might', 'like', 'to', 'hear', 'from', 'you', '.', 'man', '.', 'uhhuh', '.', "what's", 'the', 'man', 'doing', '?', '.', 'more', 'cookie', '.', 'you', 'want', 'a', 'cookie', '?', "there's", 'a', 'cookie', 'on', 'the', 'table', 'with', 'the', 'rest', 'of', 'your', 'crackers', '.', 'block', 'broke', '.', 'can', 'you', 'do', 'it', '?', 'can', 'you', 'do', 'it', 'like', 'that', '?', 'there', '.', 'there', '.', "that's", 'very', 'good', '.', 'I', 'did', 'it', '.', 'there', '.', 'there', 'Fraser', '.', "that's", 'a', 'nice', 'box', 'of', 'books', '.', "what's", 'that', '?', '.', '.', 'baby', '.', 'oh', '‡', "it's", 'a', 'baby', '.', 'Mommy', 'read', '.', 'no', '.', 'Mommy', "can't", 'read', '.', "I'm", 'busy', '.', 'you', 'read', 'the', 'book', '.', 'a', 'stool', '.', 'yes', '‡', "that's", 'the', 'stool', '.', 'you', 'want', 'to', 'sit', 'on', 'the', 'stool', 'and', 'read', 'the', 'book', '?', 'Fraser', '.', 'Mr', 'Fraser', 'yes', 'Mr', 'Fraser', '.', 'Fraser', '.', 'more', 'cookie', '.', 'more', 'cookie', '.', 'your', "cookie's", 'there', 'on', 'the', 'table', '.', 'did', 'you', 'eat', 'it', '?', 'yes', '‡', 'you', 'ate', 'it', '.', "I'll", 'give', 'you', 'another', '.', 'just', 'a', 'little', 'one', '.', 'just', 'a', 'little', 'one', '.', 'little', '.', 'yes', '.', 'little', 'one', '„', 'yes', '.', 'milk', '?', 'what', '?', 'no', '‡', 'no', 'more', '„', 'Eve', '.', "we'll", 'have', 'lunch', 'in', 'a', 'little', 'while', '.', 'you', 'eat', 'any', 'more', 'crackers', '.', 'milk', '.', 'milk', '?', 'no', '‡', 'you', "don't", 'want', 'milk', '„', 'honey', '.', "you've", 'just', 'had', 'some', 'juice', '.', "where's", 'the', 'rest', 'of', 'your', 'juice', '?', 'how_about', 'a', 'drink', 'of', 'water', '?', 'that', '?', 'what', 'is', 'that', '?', "that's", 'Mr', 'Fraser', '.', 'there', '‡', 'drink', 'the', 'water', '.', 'Fraser', 'water', '?', 'no', '‡', 'I', "don't", 'think', 'Mr', 'Fraser', 'wants', 'any', 'water', '.', 'oh', 'Fraser', '.', 'what', '?', 'bye', '.', 'bye', '?', 'where', 'are', 'you', 'going', '?', 'water', '.', 'Fraser', 'water', '.', 'will', 'you', 'ask', 'Mr', 'Fraser', 'if', "he'd", 'like', 'a', 'drink', 'of', 'water', '?', 'Fraser', 'water', '.', 'I', "don't", 'think', 'so', '.', 'Mr', 'Fraser', 'has', 'coffee', '.', 'Mr', "Fraser's", 'drinking', 'coffee', '.', 'that', '? ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-e6bfabd15c7f> in <module>
#       2 print(words)
#       3 with open('eve01_words.txt', 'a+') as newfile:
# ----> 4     newfile.write()
#       5 newfile.close()
#
# TypeError: write() takes exactly one argument (0 given)

# %%
n_CDS = n.tagged_words(participant= 'MOT')
print(n_CDS)
# Out:
# [('you', 'PRO:PER', 'you', (1, 2, 'SUBJ')), ('0v', '0V', 'v', (2, 0, 'ROOT')), ('more', 'QN', 'more', (3, 4, 'QUANT')), ('cookies', 'N', 'cookie-PL', (4, 2, 'OBJ')), ('?', '?', '', (5, 2, 'PUNCT')), ('how_about', 'ADV:INT', 'how_about', (1, 3, 'LINK')), ('another', 'QN', 'another', (2, 3, 'QUANT')), ('grahamcracker', 'N', '+n|graham+n|cracker', (3, 0, 'INCROOT')), ('?', '?', '', (4, 3, 'PUNCT')), ('would', 'MOD', 'will&COND', (1, 3, 'AUX')), ('that', 'PRO:REL', 'that', (2, 3, 'LINK')), ('do', 'V', 'do', (3, 0, 'ROOT')), ('just', 'ADV', 'just', (4, 3, 'JCT')), ('as_well', 'ADV', 'as_well', (5, 3, 'JCT')), ('?', '?', '', (6, 3, 'PUNCT')), ('here', 'ADV', 'here', (1, 0, 'INCROOT')), ('.', '.', '', (2, 1, 'PUNCT')), ('here', 'ADV', 'here', (1, 3, 'JCT')), ('you', 'PRO:PER', 'you', (2, 3, 'SUBJ')), ('go', 'V', 'go', (3, 0, 'ROOT')), ('.', '.', '', (4, 3, 'PUNCT')), ('you', 'PRO:PER', 'you', (1, 2, 'SUBJ')), ('have', 'V', 'have', (2, 0, 'ROOT')), ('another', 'QN', 'another', (3, 4, 'QUANT')), ('cookie', 'N', 'cookie', (4, 2, 'OBJ')), ('right', 'ADV', 'right', (5, 2, 'JCT')), ('on', 'PREP', 'on', (6, 2, 'JCT')), ('the', 'DET:ART', 'the', (7, 8, 'DET')), ('table', 'N', 'table', (8, 6, 'POBJ')), ('.', '.', '', (9, 2, 'PUNCT')), ('more', 'QN', 'more', (1, 2, 'QUANT')), ('juice', 'N', 'juice', (2, 0, 'INCROOT')), ('?', '?', '', (3, 2, 'PUNCT')), ('would', 'MOD', 'will&COND', (1, 3, 'AUX')), ('you', 'PRO:PER', 'you', (2, 3, 'SUBJ')), ('like', 'V', 'like', (3, 0, 'ROOT')), ('more', 'QN', 'more', (4, 5, 'QUANT')), ('grape', 'N', 'grape', (5, 6, 'MOD')), ('juice', 'N', 'juice', (6, 3, 'OBJ')), ('?', '?', '', (7, 3, 'PUNCT')), ("where's", 'ADV:INT', 'where', (1, 2, 'LINK')), ('CLITIC', 'COP', 'be&3S', (2, 0, 'ROOT')), ('your', 'DET:POSS', 'your', (3, 4, 'MOD')), ('cup', 'N', 'cup', (4, 2, 'PRED')), ('?', '?', '', (5, 2, 'PUNCT')), ('oh', 'CO', 'oh', (1, 0, 'BEG')), ('‡', 'BEG', 'beg', (2, 1, 'BEGP')), ('I', 'PRO:SUB', 'I', (3, 4, 'SUBJ')), ('took', 'V', 'take&PAST', (4, 0, 'ROOT')), ('it', 'PRO:PER', 'it', (5, 4, 'OBJ')), ('.', '.', '', (6, 4, 'PUNCT')), ('I', 'PRO:SUB', 'I', (1, 2, 'SUBJ')), ('think', 'V', 'think', (2, 0, 'ROOT')), ('that', 'PRO:DEM', 'that', (3, 4, 'SUBJ')), ('was', 'COP', 'be&PAST&13S', (4, 2, 'COMP')), ('Fraser', 'N:PROP', 'Fraser', (5, 4, 'PRED')), ('.', '.', '', (6, 2, 'PUNCT')), ("I'm", 'PRO:SUB', 'I', (1, 2, 'SUBJ')), ('CLITIC', 'COP', 'be&1S', (2, 0, 'ROOT')), ('not', 'NEG', 'not', (3, 2, 'NEG')), ('sure', 'ADJ', 'sure', (4, 2, 'PRED')), ('.', '.', '', (5, 2, 'PUNCT')), ('what', 'PRO:INT', 'what', (1, 0, 'INCROOT')), ('?', '?', '', (2, 1, 'PUNCT')), ('are', 'COP', 'be&PRES', (1, 0, 'ROOT')), ('you', 'PRO:PER', 'you', (2, 1, 'OBJ')), ('saying', 'PART', 'say-PRESP', (3, 2, 'XJCT')), ('Fraser', 'N:PROP', 'Fraser', (4, 3, 'OBJ')), ('?', '?', '', (5, 1, 'PUNCT')), ('Mr', 'N:PROP', 'Mr', (1, 2, 'SUBJ')), ('Fraser', 'N:PROP', 'Fraser', (2, 0, 'INCROOT')), ('?', '?', '', (3, 2, 'PUNCT')), ('yes', 'CO', 'yes', (1, 0, 'BEG')), ('‡', 'BEG', 'beg', (2, 1, 'BEGP')), ("that's", 'PRO:DEM', 'that', (3, 4, 'SUBJ')), ('CLITIC', 'COP', 'be&3S', (4, 0, 'ROOT')), ('much', 'ADV', 'much', (5, 6, 'JCT')), ('better', 'ADJ', 'good&CP', (6, 4, 'PRED')), ('.', '.', '', (7, 4, 'PUNCT')), ('Mr', 'N:PROP', 'Mr', (1, 2, 'SUBJ')), ('Fraser', 'N:PROP', 'Fraser', (2, 0, 'INCROOT')), ('?', '?', '', (3, 2, 'PUNCT')), ('what', 'PRO:INT', 'what', (1, 2, 'SUBJ')), ('is', 'COP', 'be&3S', (2, 0, 'ROOT')), ('that', 'PRO:DEM', 'that', (3, 2, 'PRED')), ('?', '?', '', (4, 2, 'PUNCT')), ('huh', 'CO', 'huh', (1, 0, 'INCROOT')), ('?', '?', '', (2, 1, 'PUNCT')), ('what', 'PRO:INT', 'what', (1, 2, 'SUBJ')), ('is', 'COP', 'be&3S', (2, 0, 'ROOT')), ('that', 'PRO:DEM', 'that', (3, 2, 'PRED')), ('?', '?', '', (4, 2, 'PUNCT')), ('yes', 'CO', 'yes', (1, 0, 'BEG')), ('‡', 'BEG', 'beg', (2, 1, 'BEGP')), ('a', 'DET:ART', 'a', (3, 4, 'DET')), ('fly', 'N', 'fly', (4, 0, 'INCROOT')), ('.', '.', '', (5, 4, 'PUNCT')), ('why', 'ADV:INT', 'why', (1, 5, 'LINK')), ("don't", 'MOD', 'do ...

# %%
print(n_CDS[0])
# Out:
# ('you', 'PRO:PER', 'you', (1, 2, 'SUBJ'))

# %%
utt = n.utterances(participant = 'CHI')

# %%
p = n.participant_codes()

# %%
print(utt)
# Out:
# [('CHI', 'more cookie .'), ('CHI', 'more cookie .'), ('CHI', 'more juice ?'), ('CHI', 'Fraser .'), ('CHI', 'Fraser .'), ('CHI', 'Fraser .'), ('CHI', 'Fraser .'), ('CHI', 'yeah .'), ('CHI', '(th)at ?'), ('CHI', 'a fly .'), ('CHI', 'fly .'), ('CHI', 'Mommy telephone .'), ('CHI', 'my telephone .'), ('CHI', '.'), ('CHI', 'Mommy .'), ('CHI', 'no .'), ('CHI', 'man .'), ('CHI', '.'), ('CHI', 'more cookie .'), ('CHI', 'block broke .'), ('CHI', 'there .'), ('CHI', 'I did it .'), ('CHI', 'there .'), ('CHI', 'there Fraser .'), ('CHI', '.'), ('CHI', '.'), ('CHI', 'baby .'), ('CHI', 'Mommy read .'), ('CHI', 'a stool .'), ('CHI', 'Fraser .'), ('CHI', 'Fraser .'), ('CHI', 'more cookie .'), ('CHI', 'more cookie .'), ('CHI', 'little .'), ('CHI', 'milk ?'), ('CHI', 'milk .'), ('CHI', 'that ?'), ('CHI', 'Fraser water ?'), ('CHI', 'oh Fraser .'), ('CHI', 'bye .'), ('CHI', 'water .'), ('CHI', 'Fraser water .'), ('CHI', 'Fraser water .'), ('CHI', 'that ?'), ('CHI', 'coffee .'), ('CHI', 'Fraser coffee .'), ('CHI', 'down .'), ('CHI', 'cookie .'), ('CHI', 'Mommy .'), ('CHI', 'Mommy .'), ('CHI', 'a fly .'), ('CHI', 'read the puzzle .'), ('CHI', 'read the puzzle .'), ('CHI', 'read the puzzle .'), ('CHI', 'read the puzzle .'), ('CHI', 'read the puzzle .'), ('CHI', 'Racketyboom .'), ('CHI', 'hat .'), ('CHI', '.'), ('CHI', 'm:hm .'), ('CHI', 'water .'), ('CHI', 'bottle .'), ('CHI', 'water .'), ('CHI', 'there .'), ('CHI', 'Fraser hat .'), ('CHI', 'oh Fraser hat .'), ('CHI', 'oh Fraser hat .'), ('CHI', 'Fraser hat .'), ('CHI', 'no .'), ('CHI', 'eye .'), ('CHI', 'that .'), ('CHI', '.'), ('CHI', '.'), ('CHI', 'that .'), ('CHI', 'soldier .'), ('CHI', 'soldier .'), ('CHI', 'that .'), ('CHI', 'Fraser hat .'), ('CHI', 'Eve find it .'), ('CHI', 'that .'), ('CHI', 'man .'), ('CHI', 'Eve .'), ('CHI', 'down .'), ('CHI', 'that .'), ('CHI', 'busy .'), ('CHI', 'busy .'), ('CHI', 'man a pencil .'), ('CHI', 'man a pencil .'), ('CHI', 'man .'), ('CHI', 'pencil .'), ('CHI', 'Eve pencil .'), ('CHI', 'Eve pencil .'), ('CHI', 'Eve pencil .'), ('CHI', 'man a pencil .'), ('CHI', 'pencil .'), ('CHI', 'man .'), ('CHI', 'see ya .'), ('CHI', 'read .'), ('CHI', 'read .'), ('CHI', 'Clip_clop .'), ('CHI', 'shoe .'), ('CHI', 'shoe .'), ('CHI', 'shoe .'), ('CHI', 'my .'), ('CHI', 'Mommy book .'), ('CHI', 'Racketyboom .'), ('CHI', 'Racketyboom .'), ('CHI', 'read ?'), ('CHI', 'Racketyboom .'), ('CHI', 'read ?'), ('CHI', 'read choo+choo .'), ('CHI', 'Mommy .'), ('CHI', 'Mommy .'), ('CHI', 'choo+choo .'), ('CHI', 'choo+choo .'), ('CHI', 'choo+choo .'), ('CHI', 'mi:lk .'), ('CHI', 'milk .'), ('CHI', 'cup .'), ('CHI', 'that ?'), ('CHI', 'top .'), ('CHI', 'that ?'), ('CHI', '.'), ('CHI', '.'), ('CHI', 'there .'), ('CHI', 'quack@o .'), ('CHI', 'quack@o .'), ('CHI', 'that ?'), ('CHI', 'that radio .'), ('CHI', '.'), ('CHI', 'hat .'), ('CHI', 'that .'), ('CHI', '.'), ('CHI', 'like the farm .'), ('CHI', 'cock_a_doodle_doo .'), ('CHI', 'book .'), ('CHI', 'Racketyboom .'), ('CHI', 'yeah .'), ('CHI', 'why ?'), ('CHI', 'choo+choo .'), ('CHI', 'stool .'), ('CHI', 'man stool ?'), ('CHI', 'that ?'), ('CHI', '.'), ('CHI', '.'), ('CHI', 'Neil sit .'), ('CHI', 'Neil sit .'), ('CHI', 'Neil sit ?'), ('CHI', 'Neil sit ?'), ('CHI', 'Neil sit ?'), ('CHI', 'Neil sit ?'), ('CHI', 'm:hm .'), ('CHI', 'cup .'), ('CHI', 'Neil sit .'), ('CHI', 'sit .'), ('CHI', 'Neil sit .'), ('CHI', 'Mommy !'), ('CHI', 'get it .'), ('CHI', 'that .'), ('CHI', 'a stool .'), ('CHI', 'sit .'), ('CHI', 'Neil sit .'), ('CHI', 'Neil sit .'), ('CHI', 'good girl .'), ('CHI', '.'), ('CHI', 'Neil sit that ?'), ('CHI', 'Eve seat .'), ('CHI', 'Eve seat .'), ('CHI', 'Sambo .'), ('CHI', 'Sambo .'), ('CHI', 'read ?'), ('CHI', 'why .'), ('CHI', 'Mommy .'), ('CHI', 'head .'), ('CHI', 'Mommy .'), ('CHI', 'paper .'), ('CHI', 'Mommy .'), ('CHI', 'Mommy .'), ('CHI', 'Mommy .'), ('CHI', 'lie down stool .'), ('CHI', 'lie down stool .'), ('CHI', 'man .'), ('CHI', 'Eve writing .'), ('CHI', 'write too .'), ('CHI', 'Mommy .'), ('CHI', 'paper .'), ('CHI', 'write a p ...

# %%
import linguistica as lxa
#from linguistica.datasets import brown

#lxa_object = lxa.read_corpus(brown)

lxa_object = lxa.read_corpus('/Users/ethan/Documents/GitHub/CLA_2019/Coding/Friday Exercises/Data/Brown_CHI/Adam/adam55.cha')

# %%
g = lxa_object.neighbor_graph()
# Out:
# //anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:632: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order='C', ndmin=1)

# %%
import networkx as nx
from netwulf import visualize

# %%
visualize(g)

# %%
wor = lxa_object.wordlist()
#wor

# %%
neighbors = lxa_object.words_to_neighbors()

# %%
print(neighbors)
# Out:
# {'i': ['thats', 'you', 'theres', 'all', 'about', 'with', 'gonna', 'in', 'ta'], 'you': ['put', 'like', 'i', 'in', 'get', 'keep', 'make', 'with', 'me'], 'it': ['my', 'the', 'a', 'this', 'what', 'bigger', 'grows', 'squeeze', 'some'], 'this': ['a', 'it', 'the', 'my', 'bigger', 'what', 'some', 'one', 'grows'], 'the': ['a', 'it', 'my', 'this', 'what', 'bigger', 'grows', 'squeeze', 'some'], 'a': ['this', 'the', 'my', 'it', 'bigger', 'what', 'some', 'grows', 'squeeze'], 'and': ['with', 'is', 'of', 'put', 'get', 'on', 'about', 'thats', 'keep'], 'to': ['on', 'thats', 'with', 'about', 'all', 'is', 'theres', 'up', 'i'], 'is': ['with', 'on', 'and', 'thats', 'put', 'to', 'get', 'of', 'you'], 'mommy': ['if', 'almost', 'are', 'than', 'do', 'show', 'need', 'or', 'no'], 'one': ['some', 'bigger', 'squeeze', 'grows', 'what', 'a', 'eight', 'this', 'the'], 'my': ['it', 'the', 'a', 'this', 'bigger', 'what', 'grows', 'squeeze', 'some'], 'want': ['have', 'play', 'dont', 'can', 'could', 'see', 'know', 'need', 'got'], 'now': ['do', 'make', 'see', 'get', 'mommy', 'are', 'keep', 'show', 'if'], 'im': ['finished', 'lets', 'let', 'not', 'come', 'trimpc', 'time', 'gonna', 'tip'], 'that': ['me', 'going', 'trying', 'supposed', 'go', 'hear', 'be', 'show', 'when'], 'what': ['bigger', 'grows', 'squeeze', 'some', 'eight', 'where', 'then', 'adam', 'these'], 'gonna': ['not', 'ta', 'wheres', 'theres', 'lets', 'let', 'at', 'im', 'all'], 'how': ['that', 'you', 'almost', 'me', 'going', 'trying', 'supposed', 'make', 'show'], 'dont': ['can', 'bet', 'got', 'mean', 'cant', 'say', 'wish', 'want', 'have'], 'thats': ['i', 'about', 'theres', 'with', 'all', 'to', 'at', 'of', 'gonna'], 'on': ['is', 'to', 'with', 'and', 'thats', 'of', 'about', 'theres', 'at'], 'hey': ['call', 'hi', 'and', 'care', 'four', 'oh', 'trimpc', 'ugly', 'buttons'], 'make': ['get', 'keep', 'put', 'now', 'like', 'you', 'heres', 'in', 'give'], 'up': ['again', 'yet', 'out', 'doesnt', 'for', 'to', 'time', 'wheres', 'all'], 'its': ['give', 'be', 'hold', 'outof', 'push', 'watch', 'dis', 'hear', 'go'], 'can': ['dont', 'bet', 'got', 'mean', 'cant', 'say', 'wish', 'could', 'know'], 'in': ['of', 'like', 'at', 'keep', 'dis', 'watch', 'outof', 'push', 'heres'], 'see': ['play', 'do', 'now', 'have', 'want', 'could', 'need', 'mommy', 'if'], 'have': ['want', 'could', 'need', 'dont', 'can', 'play', 'do', 'see', 'wish'], 'with': ['of', 'put', 'and', 'about', 'thats', 'theres', 'in', 'get', 'at'], 'know': ['can', 'dont', 'wish', 'got', 'bet', 'mean', 'cant', 'say', 'could'], 'play': ['see', 'want', 'have', 'do', 'could', 'need', 'dont', 'now', 'can'], 'two': ['more', 'wheres', 'for', 'time', 'at', 'not', 'im', 'gonna', 'trimpc'], 'do': ['mommy', 'see', 'if', 'could', 'now', 'need', 'play', 'have', 'almost'], 'me': ['be', 'go', 'hear', 'its', 'give', 'hold', 'like', 'come', 'that'], 'of': ['at', 'in', 'about', 'theres', 'wheres', 'dis', 'watch', 'outof', 'push'], 'all': ['ta', 'theres', 'gonna', 'about', 'wheres', 'not', 'for', 'at', 'thats'], 'no': ['or', 'when', 'care', 'show', 'are', 'than', 'wants', 'almost', 'if'], 'like': ['keep', 'give', 'in', 'outof', 'dis', 'watch', 'push', 'me', 'be'], 'put': ['get', 'keep', 'make', 'like', 'you', 'with', 'in', 'of', 'dis'], 'ta': ['not', 'gonna', 'all', 'time', 'lets', 'im', 'wheres', 'let', 'theres'], 'we': ['shes', 'walking', 'she', 'ugly', 'calling', 'song', 'playing', 'tip', 'come'], 'some': ['bigger', 'squeeze', 'grows', 'what', 'eight', 'where', 'adam', 'then', 'yeah'], 'big': ['tiger', 'carrot', 'bomb', 'little', 'dodge', 'table', 'doesnt', 'yet', 'out'], 'xxx': ['drived', 'looking', 'bananjowp', 'paul', 'everytime', 'saw', 'lighter', 'move', 'talk'], 'your': ['here', 'racing', 'over', 'cars', 'she', 'ugly', 'tip', 'calling', 'we'], 'be': ['me', 'its', 'hear', 'give', 'hold', 'go', 'come', 'outof', 'push'], 'garage': ['cafe', 'way', 'other', 'back', 'prudential', 'slidingstairsc', 'teacher', 'circle', 'finish'], 'not': ['gonna', 'im', 'ta', 'lets', 'time', 'finished', 'let', ' ...

# %%
neighbors['the']
# Out:
# ['a', 'it', 'my', 'this', 'what', 'bigger', 'grows', 'squeeze', 'some']

# %%
neighbors['take']
# Out:
# ['go', 'doggie', 'ride', 'drive', 'ball', 'get', 'up', 'pencil', 'fell']

# %%
neighbors['banjo']
# Out:
# ['other',
#  'little',
#  'back',
#  'teacher',
#  'slidingstairsc',
#  'finish',
#  'circle',
#  'prudential',
#  'carrot']

# %%
ngram = lxa_object.word_bigram_counter()

# %%
ngram
# Out:
# {('my', 'suitcase'): 3,
#  ('toomanc', 'suitcase'): 1,
#  ('monroe', 'suitcase'): 1,
#  ('find', 'dirt'): 1,
#  ('spaghetti', 'yeah'): 1,
#  ('adam', 'glove'): 2,
#  ('put', 'ball'): 3,
#  ('put', 'the'): 2,
#  ('the', 'ball'): 2,
#  ('tape', 'recorder'): 11,
#  ('ball', 'over'): 1,
#  ('over', 'here'): 1,
#  ('hit', 'mommy'): 3,
#  ('mommy', 'wall'): 1,
#  ('mommy', 'rug'): 1,
#  ('where', 'ball'): 5,
#  ('ball', 'go'): 3,
#  ('in', 'there'): 11,
#  ('adam', 'go'): 3,
#  ('go', 'get'): 7,
#  ('get', 'it'): 10,
#  ('get', 'stuck'): 2,
#  ('adam', 'get'): 4,
#  ('bye', 'see'): 1,
#  ('see', 'later'): 1,
#  ('later', 'again'): 1,
#  ('adam', 'ball'): 2,
#  ('who', 'dat'): 56,
#  ('dat', 'that'): 107,
#  ('tootooo', 'train'): 1,
#  ('train', 'track'): 10,
#  ('read', 'dat'): 10,
#  ('that', 'train'): 1,
#  ('train', 'train'): 2,
#  ('adam', 'sit'): 10,
#  ('sit', 'down'): 11,
#  ('down', 'book'): 1,
#  ('choochoo', 'train'): 5,
#  ('diesel', 'motor'): 1,
#  ('motor', 'no'): 1,
#  ('no', 'no'): 3,
#  ('no', 'motor'): 1,
#  ('baggage', 'car'): 1,
#  ('streamline', 'coach'): 1,
#  ('yyy', 'car'): 1,
#  ('dining', 'car'): 1,
#  ('snow', 'plow'): 1,
#  ('flat', 'car'): 2,
#  ('mail', 'car'): 2,
#  ('tank', 'car'): 2,
#  ('box', 'car'): 2,
#  ('xxx', 'put'): 1,
#  ('put', 'baby'): 2,
#  ('sleeping', 'car'): 1,
#  ('dining', 'where'): 1,
#  ('where', 'eat'): 1,
#  ('stop', 'car'): 1,
#  ('look', 'like'): 2,
#  ('like', 'dat'): 1,
#  ('call', 'tootooc'): 1,
#  ('tootooc', 'train'): 9,
#  ('call', 'caboose'): 1,
#  ('work', 'with'): 1,
#  ('old', 'time'): 1,
#  ('time', 'train'): 1,
#  ('train', 'right'): 1,
#  ('right', 'dere'): 25,
#  ('dere', 'there'): 37,
#  ('sweep', 'broom'): 6,
#  ('find', 'pocket'): 1,
#  ('fix', 'bike'): 1,
#  ('go', 'floor'): 1,
#  ('floor', 'take'): 1,
#  ('take', 'off'): 13,
#  ('urlerc', 'take'): 1,
#  ('off', 'take'): 1,
#  ('write', 'adam'): 2,
#  ('adam', 'take'): 3,
#  ('off', 'paper'): 1,
#  ('off', 'adam'): 1,
#  ('adam', 'paper'): 1,
#  ('that', 'pretty'): 1,
#  ('adam', 'adam'): 4,
#  ('dl', 'al'): 2,
#  ('al', 'ml'): 4,
#  ('adam', 'ml'): 1,
#  ('write', 'already'): 1,
#  ('i', 'adam'): 5,
#  ('adam', 'al'): 3,
#  ('write', 'pencil'): 2,
#  ('pencil', 'adam'): 1,
#  ('sit', 'tow'): 1,
#  ('tow', 'truck'): 13,
#  ('truck', 'okay'): 1,
#  ('hit', 'tow'): 2,
#  ('truck', 'knee'): 1,
#  ('so', 'sorry'): 1,
#  ('sorry', 'tow'): 1,
#  ('find', 'truck'): 3,
#  ('locomotive', 'caboose'): 3,
#  ('yeah', 'locomotive'): 1,
#  ('adam', 'locomotive'): 2,
#  ('bye', 'caboose'): 1,
#  ('bye', 'doggie'): 1,
#  ('woofo', 'woofo'): 4,
#  ('bye', 'donzduck'): 1,
#  ('pinocchio', 'mommy'): 1,
#  ('xxx', 'track'): 1,
#  ('track', 'train'): 2,
#  ('put', 'pajamas'): 4,
#  ('pajamas', 'on'): 4,
#  ('put', 'dat'): 1,
#  ('that', 'pajamas'): 1,
#  ('pajamas', 'my'): 1,
#  ('my', 'car'): 1,
#  ('where', 'racket'): 2,
#  ('daddy', 'racket'): 3,
#  ('racket', 'go'): 1,
#  ('adam', 'racket'): 2,
#  ('briefcase', 'ursulas'): 1,
#  ('ursulas', 'briefcase'): 1,
#  ('up', 'no'): 1,
#  ('ul', 'pl'): 1,
#  ('pl', 'up'): 1,
#  ('sit', 'dere'): 1,
#  ('squ', 'down'): 1,
#  ('two', 'foot'): 1,
#  ('two', 'feet'): 4,
#  ('feet', 'yeah'): 1,
#  ('two', 'sock'): 2,
#  ('two', 'like'): 1,
#  ('like', 'adam'): 3,
#  ('adam', 'two'): 3,
#  ('that', 'knee'): 2,
#  ('right', 'a'): 1,
#  ('a', 'arm'): 1,
#  ('all', 'qua'): 1,
#  ('my', 'paper'): 2,
#  ('adam', 'pencil'): 4,
#  ('joshua', 'shirt'): 1,
#  ('foot', 'dere'): 1,
#  ('there', 'joshua'): 1,
#  ('joshua', 'foot'): 1,
#  ('foot', 'adam'): 1,
#  ('adam', 'busy'): 1,
#  ('busy', 'bulldozer'): 14,
#  ('pick', 'dirt'): 4,
#  ('dirt', 'up'): 10,
#  ('big', 'tow'): 1,
#  ('truck', 'pick'): 1,
#  ('pick', 'joshua'): 1,
#  ('joshua', 'dirt'): 1,
#  ('ride', 'dat'): 14,
#  ('that', 'tractor'): 1,
#  ('racket', 'write'): 1,
#  ('write', 'dat'): 2,
#  ('dirt', 'shovel'): 1,
#  ('shovel', 'up'): 2,
#  ('pick', 'roadgrader'): 1,
#  ('roadgrader', 'dirt'): 1,
#  ('adam', 'xxx'): 1,
#  ('xxx', 'roadgrader'): 1,
#  ('adam', 'ride'): 5,
#  ('choochoo', 'go'): 1,
#  ('where', 'put'): 1,
#  ('put', 'fire'): 1,
#  ('pull', 'roadgrader'): 2,
#  ('hit', 'nail'): 4,
#  ('just', 'sharp'): 1,
#  ('hit', 'dat'): 1,
#  ('roadgrader', 'hit'): 1,
#  ('hit', 'robie'): 1,
#  ('robie', 'nail'): 1,
#  ('hit', 'adam'): 1,
#  ('adam', 'roadgrader'): 1,
#  ('pick', 'glove'): 1,
#  ('pick', 'paper'): 1,
#  ('put', 'away'): 1,
#  ('nail', 'mommy'): 1,
#  ('rug', 'rug'): 3,
#  ('rug', 'in'): 1,
#  ('green', 'rug'): 2,
#  ('doggie', 'doggie'): 6,
#  ('hurt', 'doggie'): 2,
#  ('hit', 'shoulder'): 1,
#  ('yeah', 'on'): 1,
#  ('on', 'table'): 1,
#  ('my', 'mosquito'): 1,
#  ('hit', 'arm'): 1,
#  ('hit', 'mosquito'): 1,
#  ('busby', 'bulldozer'): 1,
#  ('up', 'dere'): 7,
#  ('adam', 'buy'): 1,
#  ('buy', 'bulldozer'): 1,
#  ('busy', 'motor'): 1,
#  ('that', 'man'): 3,
#  ('man', 'man'): 4,
#  ('man', 'drive'): 1,
#  ('drive', 'busy'): 3,
#  ('drive', 'up'): 1,
#  ('put', 'dirt'): 4,
#  ('put', 'shovel'): 1,
#  ('busy', 'busy'): 7,
#  ('drive', 'drive'): 1,
#  ('where', 'tractor'): 1,
#  ('tractor', 'go'): 1,
#  ('where', 'go'): 4,
#  ('truck', 'train'): 1,
#  ('two', 'men'): 1,
#  ('come', 'on'): 4,
#  ('on', 'pal'): 1,
#  ('pal', 'let'): 1,
#  ('let', 'go'): 1,
#  ('my', 'book'): 3,
#  ('circus', 'doctor'): 1,
#  ('doctor', 'doctor'): 2,
#  ('doctor', 'dan'): 12,
#  ('dan', 'dan'): 1,
#  ('dan', 'book'): 1,
#  ('adam', 'daddy'): 1,
#  ('daddy', 'suitcase'): 2,
#  ('my', 'cromer'): 1,
#  ('cromer', 'suitcase'): 4,
#  ('cromer', 'cromer'): 2,
#  ('adam', 'suitcase'): 1,
#  ('my', 'pocketbook'): 1,
#  ('sit', 'munroe'): 1,
#  ('munroe', 'car'): 2,
#  ('sit', 'miss'): 1,
#  ('miss', 'munroe'): 2,
#  ('ride', 'tow'): 1,
#  ('put', 'miss'): 1,
#  ('munroe', 'tow'): 1,
#  ('where', 'doggie'): 3,
#  ('my', 'doggie'): 1,
#  ('find', 'doggie'): 2,
#  ('put', 'texaco'): 1,
#  ('texaco', 'star'): 2,
#  ('get', 'cliffy'): 1,
#  ('cliffy', 'x'): 2,
#  ('x', '5'): 1,
#  ('x', '3'): 1,
#  ('bye', 'lion'): 2,
#  ('two', 'bootie'): 1,
#  ('two', 'boot'): 5,
#  ('put', 'adam'): 6,
#  ('okay', 'adam'): 1,
#  ('adam', 'doggie'): 3,
#  ('take', 'eye'): 1,
#  ('eye', 'off'): 1,
#  ('nose', 'off'): 18,
#  ('take', 'nose'): 15,
#  ('you', 'take'): 1,
#  ('you', 'nose'): 1,
#  ('toomanc', 'take'): 2,
#  ('take', 'lion'): 1,
#  ('lion', 'nose'): 1,
#  ('doggie', 'take'): 1,
#  ('nose', 'adam'): 1,
#  ('adam', 'nose'): 1,
#  ('no', 'adam'): 6,
#  ('adam', 'toomanc'): 1,
#  ('adam', 'too'): 1,
#  ('too', 'take'): 1,
#  ('donzduck', 'take'): 1,
#  ('fire', 'take'): 2,
#  ('bird', 'take'): 1,
#  ('that', 'piggie'): 1,
#  ('baby', 'baby'): 1,
#  ('baby', 'doggie'): 1,
#  ('dog', 'pepper'): 1,
#  ('pepper', 'pepper'): 2,
#  ('see', 'record'): 4,
#  ('record', 'again'): 3,
#  ('go', 'work'): 5,
#  ('record', 'go'): 1,
#  ('off', 'here'): 1,
#  ('i', 'go'): 5,
#  ('go', 'take'): 1,
#  ('go', 'adam'): 1,
#  ('that', 'record'): 1,
#  ('excuse', 'me'): 7,
#  ('sit', 'adam'): 1,
#  ('peekaboo', 'peekaboo'): 4,
#  ('mommy', 'mommy'): 2,
#  ('mommy', 'look'): 1,
#  ('choochoo', 'track'): 1,
#  ('car', 'train'): 2,
#  ('what', 'is'): 1,
#  ('is', 'in'): 1,
#  ('there', 'mommy'): 2,
#  ('what', 'in'): 2,
#  ('that', 'mommy'): 5,
#  ('two', 'rug'): 4,
#  ('adam', 'hit'): 1,
#  ('hit', 'piggie'): 1,
#  ('piggie', 'own'): 1,
#  ('own', 'toe'): 1,
#  ('part', 'broom'): 2,
#  ('me', 'urlerc'): 3,
#  ('urlerc', 'part'): 1,
#  ('where', 'broom'): 1,
#  ('broom', 'go'): 1,
#  ('go', 'mommy'): 3,
#  ('trash', 'mommy'): 1,
#  ('adam', 'see'): 2,
#  ('see', 'them'): 1,
#  ('oh', 'no'): 2,
#  ('adam', 'find'): 1,
#  ('no', 'car'): 1,
#  ('car', 'broke'): 3,
#  ('broke', 'find'): 1,
#  ('two', 'truck'): 1,
#  ('truck', 'fire'): 1,
#  ('man', 'toomanc'): 1,
#  ('toomanc', 'humptyzdumpty'): 1,
#  ('sat', 'wall'): 1,
#  ('man', 'all'): 1,
#  ('all', 'kings'): 1,
#  ('kings', 'men'): 1,
#  ('humptyzdumpty', 'together'): 1,
#  ('together', 'again'): 2,
#  ('ricky', 'fix'): 2,
#  ('lilly', 'lilly'): 1,
#  ('fix', 'lilly'): 1,
#  ('sing', 'jesus'): 1,
#  ('jesus', 'loves'): 1,
#  ('loves', 'me'): 1,
#  ('me', 'so'): 2,
#  ('daddy', 'adam'): 1,
#  ('take', 'adam'): 4,
#  ('adam', 'jesus'): 1,
#  ('jesus', 'love'): 1,
#  ('love', 'me'): 1,
#  ('so', 'coat'): 1,
#  ('adam', 'driving'): 2,
#  ('up', 'up'): 2,
#  ('there', 'up'): 1,
#  ('put', 'up'): 1,
#  ('daddy', 'go'): 11,
#  ('daddy', 'went'): 2,
#  ('went', 'school'): 1,
#  ('that', 'daddy'): 3,
#  ('see', 'it'): 1,
#  ('i', 'take'): 1,
#  ('recorder', 'urlerc'): 1,
#  ('mommy', 'urlerc'): 1,
#  ('urlerc', 'daddy'): 1,
#  ('daddy', 'daddy'): 1,
#  ('daddy', 'work'): 1,
#  ('go', 'pick'): 1,
#  ('pick', 'up'): 2,
#  ('go', 'bambi'): 1,
#  ('okay', 'bambi'): 1,
#  ('march', 'bambi'): 1,
#  ('mommy', 'march'): 1,
#  ('greenzjeans', 'march'): 1,
#  ('bambi', 'march'): 1,
#  ('bear', 'march'): 2,
#  ('kangaroo', 'bear'): 1,
#  ('bumble', 'bee'): 2,
#  ('get', 'bumble'): 1,
#  ('bee', 'alright'): 1,
#  ('tractor', 'tow'): 1,
#  ('tow', 'track'): 1,
#  ('toomanc', 'go'): 1,
#  ('go', 'man'): 1,
#  ('adam', 'drive'): 5,
#  ('drive', 'dat'): 3,
#  ('train', 'tootooc'): 1,
#  ('get', 'car'): 1,
#  ('daddy', 'make'): 1,
#  ('make', 'go'): 1,
#  ('mommy', 'daddy'): 2,
#  ('daddy', 'mommy'): 1,
#  ('bunnyrabbit', 'go'): 1,
#  ('i', 'can'): 1,
#  ('can', 'take'): 1,
#  ('adam', 'panda'): 1,
#  ('panda', 'march'): 1,
#  ('okay', 'marching'): 1,
#  ('marching', 'bear'): 4,
#  ('okay', 'bear'): 1,
#  ('adam', 'walk'): 2,
#  ('put', 'walk'): 2,
#  ('ready', 'greenjeans'): 1,
#  ('greenjeans', 'marching'): 1,
#  ('that', 'adam'): 8,
#  ('mr', 'cromer'): 1,
#  ('cromer', 'right'): 1,
#  ('see', 'adam'): 2,
#  ('see', 'mommy'): 1,
#  ('see', 'roadgrader'): 1,
#  ('truck', 'truck'): 2,
#  ('see', 'truck'): 1,
#  ('yeah', 'too'): 1,
#  ('too', 'truck'): 1,
#  ('ball', 'outside'): 2,
#  ('outside', 'okay'): 1,
#  ('spill', 'rug'): 1,
#  ('spill', 'face'): 1,
#  ('spill', 'mommy'): 1,
#  ('mommy', 'face'): 1,
#  ('get', 'you'): 1,
#  ('adam', 'up'): 3,
#  ('get', 'over'): 2,
#  ('over', 'ball'): 1,
#  ('ball', 'where'): 1,
#  ('go', 'over'): 1,
#  ('hi', 'hi'): 1,
#  ('adam', 'water'): 1,
#  ('xxx', 'bear'): 1,
#  ('bear', 'water'): 1,
#  ('cromer', 'xxx'): 1,
#  ('xxx', 'more'): 1,
#  ('more', 'water'): 1,
#  ('urlerc', 'water'): 1,
#  ('go', 'go'): 1,
#  ('it', 'mommy'): 1,
#  ('get', 'water'): 1,
#  ('water', 'mommy'): 1,
#  ('suitcase', 'water'): 1,
#  ('oh', 'tummy'): 1,
#  ('shirt', 'shirt'): 2,
#  ('where', 'daddy'): 2,
#  ('adam', 'wipe'): 1,
#  ('wipe', 'off'): 2,
#  ('off', 'cromer'): 1,
#  ('cromer', 'urlerc'): 1,
#  ('urlerc', 'urlerc'): 1,
#  ('urlerc', 'car'): 1,
#  ('come', 'adam'): 2,
#  ('adam', 'over'): 1,
#  ('adam', 'house'): 1,
#  ('robbie', 'driving'): 1,
#  ('driving', 'too'): 1,
#  ('robbie', 'too'): 1,
#  ('too', 'driving'): 1,
#  ('hi', 'cromer'): 1,
#  ('cromer', 'go'): 1,
#  ('go', 'school'): 1,
#  ('hobo', 'truck'): 1,
#  ('telephone', 'telephone'): 2,
#  ('okay', 'bye'): 1,
#  ('shoe', 'go'): 2,
#  ('where', 'shoe'): 1,
#  ('where', 'other'): 2,
#  ('other', 'one'): 2,
#  ('throw', 'daddy'): 2,
#  ('throw', 'throw'): 2,
#  ('doctor', 'dans'): 1,
#  ('dans', 'circus'): 1,
#  ('dan', 'circus'): 6,
#  ('at', 'circus'): 1,
#  ('lion', 'tamer'): 1,
#  ('clown', 'clown'): 1,
#  ('lady', 'urlerc'): 5,
#  ('circus', 'dan'): 1,
#  ('big', 'shoe'): 1,
#  ('bite', 'doggie'): 7,
#  ('to', 'toomanc'): 1,
#  ('bird', 'get'): 1,
#  ('get', 'way'): 1,
#  ('tattoo', 'man'): 6,
#  ('man', 'go'): 2,
#  ('yyy', 'hand'): 1,
#  ('fell', 'down'): 9,
#  ('bandaid', 'on'): 2,
#  ('adam', 'bandaid'): 1,
#  ('take', 'boot'): 2,
#  ('boot', 'off'): 1,
#  ('boot', 'on'): 1,
#  ('adam', 'on'): 1,
#  ('adam', 'boot'): 1,
#  ('bite', 'pinocchio'): 1,
#  ('fall', 'down'): 1,
#  ('blow', 'nose'): 1,
#  ('nose', 'mommy'): 1,
#  ('a', 'tattoo'): 1,
#  ('man', 'fell'): 1,
#  ('down', 'rug'): 1,
#  ('who', 'adam'): 1,
#  ('adam', 'fell'): 3,
#  ('hit', 'door'): 1,
#  ('door', 'head'): 1,
#  ('put', 'hot'): 1,
#  ('beep', 'beep'): 4,
#  ('move', 'bike'): 1,
#  ('put', 'racket'): 4,
#  ('racket', 'up'): 4,
#  ('k', 'your'): 1,
#  ('write', 'daddy'): 7,
#  ('write', 'paper'): 2,
#  ('you', 'write'): 1,
#  ('paper', 'go'): 3,
#  ('where', 'paper'): 2,
#  ('paper', 'mommy'): 1,
#  ('get', 'book'): 1,
#  ('joshua', 'book'): 1,
#  ('play', 'piano'): 1,
#  ('man', 'doing'): 1,
#  ('adam', 'again'): 1,
#  ('put', 'coat'): 1,
#  ('coat', 'on'): 1,
#  ('coat', 'too'): 1,
#  ('mr', 'walter'): 6,
#  ('walter', 'write'): 1,
#  ('hi', 'mommy'): 2,
#  ('that', 'lady'): 1,
#  ('no', 'dat'): 1,
#  ('walter', 'like'): 1,
#  ('like', 'man'): 2,
#  ('man', 'walter'): 2,
#  ('doing', 'mommy'): 1,
#  ('no', 'walter'): 1,
#  ('walter', 'in'): 2,
#  ('give', 'cromer'): 2,
#  ('i', 'give'): 1,
#  ('give', 'it'): 1,
#  ('to', 'whom'): 1,
#  ('mommy', 'read'): 2,
#  ('read', 'book'): 2,
#  ('book', 'before'): 2,
#  ('get', 'me'): 1,
#  ('me', 'up'): 1,
#  ('adam', 'funny'): 2,
#  ('i', 'mommy'): 1,
#  ('mommy', 'i'): 1,
#  ('go', 'haha'): 1,
#  ('haha', 'haha'): 1,
#  ('went', 'to'): 1,
#  ('to', 'school'): 1,
#  ('daddy', 'paper'): 1,
#  ('daddy', 'cromer'): 2,
#  ('mommy', 'cromer'): 1,
#  ('adam', 'cromer'): 1,
#  ('telephone', 'perro'): 1,
#  ('my', 'pencil'): 5,
#  ('see', 'clock'): 2,
#  ('spaghetti', 'cromer'): 1,
#  ('my', 'coat'): 1,
#  ('cromer', 'coat'): 1,
#  ('i', 'help'): 1,
#  ('my', 'joshua'): 1,
#  ('pencil', 'joshua'): 1,
#  ('see', 'daddy'): 2,
#  ('turn', 'on'): 1,
#  ('give', 'me'): 2,
#  ('pencil', 'yeah'): 1,
#  ('yeah', 'sure'): 2,
#  ('sure', 'mommy'): 1,
#  ('two', 'boy'): 1,
#  ('record', 'see'): 1,
#  ('record', 'tape'): 1,
#  ('see', 'that'): 1,
#  ('off', 'wagon'): 1,
#  ('wagon', 'okay'): 1,
#  ('adam', 'pillow'): 2,
#  ('mommy', 'pillow'): 1,
#  ('daddy', 'pillow'): 1,
#  ('poor', 'doggie'): 1,
#  ('put', 'together'): 1,
#  ('where', 'thread'): 1,
#  ('doggie', 'fix'): 2,
#  ('fix', 'it'): 2,
#  ('doggie', 'pepper'): 1,
#  ('move', 'doggie'): 2,
#  ('doggie', 'over'): 1,
#  ('on', 'dog'): 1,
#  ('eight', 'nine'): 2,
#  ('nine', 'ten'): 2,
#  ('ten', 'go'): 1,
#  ('lion', 'lion'): 4,
#  ('my', 'read'): 1,
#  ('turn', 'around'): 7,
#  ('ball', 'ball'): 3,
#  ('hit', 'ball'): 4,
#  ('my', 'pillow'): 1,
#  ('like', 'pillow'): 1,
#  ('i', 'play'): 1,
#  ('play', 'racket'): 1,
#  ('you', 'doggie'): 2,
#  ('you', 'ride'): 2,
#  ('ride', 'roadgrader'): 2,
#  ('roadgrader', 'too'): 2,
#  ('take', 'roadgrader'): 1,
#  ('stay', 'there'): 1,
#  ('there', 'roadgrader'): 1,
#  ('pencil', 'for'): 1,
#  ('for', 'roadgrader'): 1,
#  ('here', 'right'): 1,
#  ('pick', 'urlerc'): 1,
#  ('thankyou', 'urlerc'): 1,
#  ('lady', 'look'): 1,
#  ('like', 'urlerc'): 1,
#  ('oh', 'wash'): 1,
#  ('wash', 'hand'): 5,
#  ('do', 'wash'): 3,
#  ('lady', 'elephant'): 2,
#  ('urlerc', 'elephant'): 1,
#  ('adam', 'smith'): 1,
#  ('on', 'donzduck'): 1,
#  ('kitty', 'kitty'): 5,
#  ('adam', 'ladder'): 1,
#  ('who', 'did'): 1,
#  ('did', 'dat'): 1,
#  ('show', 'urlerc'): 1,
#  ('urlerc', 'who'): 1,
#  ('like', 'bambi'): 2,
#  ('adam', 'bambi'): 4,
#  ('no', 'bunnyrabbit'): 1,
#  ('train', 'choochoo'): 2,
#  ('like', 'perro'): 6,
#  ('my', 'bunnyrabbit'): 1,
#  ('adam', 'wet'): 1,
#  ('wet', 'pants'): 2,
#  ('kick', 'ball'): 1,
#  ('sorry', 'urlerc'): 1,
#  ('that', 'alright'): 1,
#  ('kick', 'adam'): 1,
#  ('watch', 'urlerc'): 1,
#  ('no', 'kick'): 1,
#  ('kick', 'box'): 1,
#  ('down', 'mommy'): 1,
#  ('take', 'out'): 2,
#  ('oh', 'oh'): 3,
#  ('get', 'a'): 1,
#  ('a', 'hand'): 1,
#  ('hand', 'out'): 1,
#  ('chicken', 'come'): 1,
#  ('come', 'out'): 1,
#  ('mine', 'take'): 1,
#  ('adam', 'mouth'): 2,
#  ('bite', 'adam'): 2,
#  ('bite', 'mommy'): 1,
#  ('mommy', 'mouth'): 1,
#  ('bite', 'cromer'): 4,
#  ('cromer', 'mouth'): 4,
#  ('bit', 'urlerc'): 1,
#  ('urlerc', 'mouth'): 1,
#  ('recorder', 'bite'): 1,
#  ('bite', 'mouth'): 1,
#  ('hear', 'tape'): 1,
#  ('recorder', 'ready'): 4,
#  ('move', 'over'): 1,
#  ('over', 'tape'): 1,
#  ('careful', 'microphone'): 1,
#  ('adam', 'you'): 1,
#  ('you', 'driver'): 3,
#  ('driver', 'doggie'): 1,
#  ('you', 'big'): 3,
#  ('big', 'driver'): 2,
#  ('big', 'tired'): 1,
#  ('daddy', 'desk'): 2,
#  ('more', 'daddy'): 1,
#  ('desk', 'doggie'): 1,
#  ('tummy', 'hurt'): 3,
#  ('doggies', 'tummy'): 1,
#  ('big', 'truck'): 1,
#  ('big', 'hill'): 1,
#  ('bite', 'the'): 1,
#  ('the', 'dirt'): 1,
#  ('bite', 'dirt'): 1,
#  ('no', 'tear'): 1,
#  ('tear', 'book'): 1,
#  ('car', 'car'): 2,
#  ('green', 'car'): 4,
#  ('car', 'green'): 2,
#  ('purple', 'red'): 1,
#  ('red', 'green'): 1,
#  ('bambi', 'green'): 2,
#  ('green', 'a'): 1,
#  ('hurt', 'head'): 1,
#  ('fell', 'hm'): 1,
#  ('up', 'sky'): 1,
#  ('you', 'get'): 2,
#  ('get', 'cromer'): 1,
#  ('it', 'cromer'): 2,
#  ('you', 'throw'): 1,
#  ('throw', 'ball'): 1,
#  ('ball', 'cromer'): 1,
#  ('where', 'light'): 2,
#  ('light', 'go'): 2,
#  ('mommy', 'ball'): 1,
#  ('where', 'glove'): 2,
#  ('glove', 'go'): 2,
#  ('sorry', 'cromer'): 2,
#  ('cromer', 'sorry'): 1,
#  ('sorry', 'pepper'): 1,
#  ('ball', 'pepper'): 2,
#  ('lost', 'shoe'): 2,
#  ('shoe', 'mommy'): 2,
#  ('no', 'knock'): 1,
#  ('knock', 'bambi'): 1,
#  ('bambi', 'off'): 1,
#  ('stop', 'it'): 1,
#  ('it', 'bambi'): 1,
#  ('walk', 'adam'): 4,
#  ('put', 'lap'): 1,
#  ('down', 'bambi'): 2,
#  ('call', 'daddy'): 2,
#  ('home', 'mommy'): 1,
#  ('adam', 'home'): 1,
#  ('bambi', 'home'): 1,
#  ('cromer', 'home'): 1,
#  ('jowha', 'home'): 1,
#  ('kenny', 'home'): 1,
#  ('doggie', 'home'): 1,
#  ('ball', 'home'): 2,
#  ('you', 'perro'): 1,
#  ('perro', 'home'): 2,
#  ('man', 'tractor'): 1,
#  ('tractor', 'drive'): 1,
#  ('drive', 'tractor'): 1,
#  ('tractor', 'over'): 1,
#  ('over', 'dere'): 1,
#  ('there', 'home'): 1,
#  ('tractor', 'home'): 1,
#  ('busy', 'bull'): 1,
#  ('bull', 'busy'): 1,
#  ('bulldozer', 'home'): 1,
#  ('dirt', 'home'): 2,
#  ('bike', 'home'): 1,
#  ('ricky', 'home'): 1,
#  ('susy', 'susy'): 1,
#  ('susy', 'home'): 1,
#  ('look', 'bambi'): 1,
#  ('bambi', 'adam'): 1,
#  ('that', 'eye'): 1,
#  ('two', 'ear'): 1,
#  ('two', 'eye'): 1,
#  ('home', 'home'): 3,
#  ('ursula', 'home'): 1,
#  ('recorder', 'home'): 1,
#  ('door', 'home'): 1,
#  ('make', 'cromer'): 3,
#  ('cromer', 'doctor'): 1,
#  ('tatoo', 'man'): 5,
#  ('man', 'cromer'): 1,
#  ('my', 'adam'): 1,
#  ('tootooc', 'coming'): 1,
#  ('part', 'apple'): 3,
#  ('part', 'basket'): 1,
#  ('go', 'belong'): 1,
#  ('where', 'apple'): 2,
#  ('apple', 'go'): 2,
#  ('apple', 'apple'): 1,
#  ('bambi', 'go'): 1,
#  ('look', 'look'): 1,
#  ('move', 'pocket'): 1,
#  ('move', 'chair'): 2,
#  ('move', 'move'): 1,
#  ('doggie', 'hurt'): 1,
#  ('hurt', 'you'): 1,
#  ('where', 'roadgrader'): 1,
#  ('hurt', 'tummy'): 1,
#  ('tummy', 'doggie'): 1,
#  ('change', 'diaper'): 2,
#  ('adam', 'change'): 1,
#  ('two', 'knee'): 1,
#  ('two', 'elbow'): 1,
#  ('two', 'leg'): 1,
#  ('yyy', 'go'): 1,
#  ('tootooc', 'tootooc'): 4,
#  ('tootooc', 'go'): 1}
