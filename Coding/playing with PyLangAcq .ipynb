# %%
import pylangacq as pla
from os import chdir as cd
#pathin = '/Users/ethan/Documents/GitHub/CLA_2019/Coding/Friday Exercises/Data/NewmanRatner/24/'
pathin = '/Users/ethan/Documents/GitHub/CLA_2019/Coding/Friday Exercises/Data/Brown/Eve'

# %%
cd(pathin)
n = pla.read_chat('eve01.cha')

# %%
#dir(n)

# %%
#s = n.tagged_sents()
#print(s)

# %%
age = (sorted(n.age().values()))
print(age)
# Out:
# [(1, 6, 0)]

# %%
#convert age to months
age_years = age[0][0]
age_months = age[0][1]
age_months = age_months + age_years*12
print(age_months)
# Out:
# 18

# %%
#print(n.words())
#w = n.tagged_words()
#print(w)

# %%
s = n.sents(participant = 'CHI')
#print(s)
c = n.concordance('what')
print(c)
# Out:
# ['                     what ?', '                     what is that ?', '                     what is that ?', '                     what ?', '                     what is that ?', '                     what ?', '                     what is that ?', '                 now what ?', '                     what ?', '                     what ?', '                 and what did you do with it ?', '                     what are you doing ?', '                     what are you doing ?', '                     what ?', "        I don't know what you're saying about the hat .", '                     what is that ?', '                     what do you want me to do with it ?', '                     what do you want me to do with it ?', '                     what ?', '              well ‡ what are you doing in the corner ?', '                     what ?', '                     what is that ?', '                your what ?', '                     what ?', '                     what is that ?', '    
# ...

# %%
words = n.words()
#print(words)
#with open('eve01_words.txt', 'a+') as newfile:
#    newfile.write()
#newfile.close()

# %%
n_CDS = n.tagged_words(participant= 'MOT')
#print(n_CDS)

# %%
print(n_CDS[0])
# Out:
# ('you', 'PRO:PER', 'you', (1, 2, 'SUBJ'))

# %%
utt = n.utterances(participant = 'CHI')

# %%
p = n.participant_codes()

# %%
print(utt)
# Out:
# [('CHI', 'more cookie .'), ('CHI', 'more cookie .'), ('CHI', 'more juice ?'), ('CHI', 'Fraser .'), ('CHI', 'Fraser .'), ('CHI', 'Fraser .'), ('CHI', 'Fraser .'), ('CHI', 'yeah .'), ('CHI', '(th)at ?'), ('CHI', 'a fly .'), ('CHI', 'fly .'), ('CHI', 'Mommy telephone .'), ('CHI', 'my telephone .'), ('CHI', '.'), ('CHI', 'Mommy .'), ('CHI', 'no .'), ('CHI', 'man .'), ('CHI', '.'), ('CHI', 'more cookie .'), ('CHI', 'block broke .'), ('CHI', 'there .'), ('CHI', 'I did it .'), ('CHI', 'there .'), ('CHI', 'there Fraser .'), ('CHI', '.'), ('CHI', '.'), ('CHI', 'baby .'), ('CHI', 'Mommy read .'), ('CHI', 'a stool .'), ('CHI', 'Fraser .'), ('CHI', 'Fraser .'), ('CHI', 'more cookie .'), ('CHI', 'more cookie .'), ('CHI', 'little .'), ('CHI', 'milk ?'), ('CHI', 'milk .'), ('CHI', 'that ?'), ('CHI', 'Fraser water ?'), ('CHI', 'oh Fraser .'), ('CHI', 'bye .'), ('CHI', 'water .'), ('CHI', 'Fraser water .'), ('CHI', 'Fraser water .'), ('CHI', 'that ?'), ('CHI', 'coffee .'), ('CHI', 'Fraser coffee .'),
# ...

# %%
import linguistica as lxa
#from linguistica.datasets import brown

#lxa_object = lxa.read_corpus(brown)

lxa_object = lxa.read_corpus('/Users/ethan/Documents/GitHub/CLA_2019/Coding/Friday Exercises/Data/Brown_CHI/Adam/adam55.cha')

# %%
g = lxa_object.neighbor_graph()
# Out:
# //anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:632: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order='C', ndmin=1)

# %%
import networkx as nx
from netwulf import visualize

# %%
visualize(g)
# Out:
# (None, None)

# %%
wor = lxa_object.wordlist()
#wor

# %%
neighbors = lxa_object.words_to_neighbors()

# %%
print(neighbors)
# Out:
# {'i': ['thats', 'you', 'theres', 'all', 'about', 'with', 'gonna', 'in', 'ta'], 'you': ['put', 'like', 'i', 'in', 'get', 'keep', 'make', 'with', 'me'], 'it': ['my', 'the', 'a', 'this', 'what', 'bigger', 'grows', 'squeeze', 'some'], 'this': ['a', 'it', 'the', 'my', 'bigger', 'what', 'some', 'one', 'grows'], 'the': ['a', 'it', 'my', 'this', 'what', 'bigger', 'grows', 'squeeze', 'some'], 'a': ['this', 'the', 'my', 'it', 'bigger', 'what', 'some', 'grows', 'squeeze'], 'and': ['with', 'is', 'of', 'put', 'get', 'on', 'about', 'thats', 'keep'], 'to': ['on', 'thats', 'with', 'about', 'all', 'is', 'theres', 'up', 'i'], 'is': ['with', 'on', 'and', 'thats', 'put', 'to', 'get', 'of', 'you'], 'mommy': ['if', 'almost', 'are', 'than', 'do', 'show', 'need', 'or', 'no'], 'one': ['some', 'bigger', 'squeeze', 'grows', 'what', 'a', 'eight', 'this', 'the'], 'my': ['it', 'the', 'a', 'this', 'bigger', 'what', 'grows', 'squeeze', 'some'], 'want': ['have', 'play', 'dont', 'can', 'could', 'see', 'know', 'need',
# ...

# %%
neighbors['the']
# Out:
# ['a', 'it', 'my', 'this', 'what', 'bigger', 'grows', 'squeeze', 'some']

# %%
neighbors['take']
# Out:
# ['go', 'doggie', 'ride', 'drive', 'ball', 'get', 'up', 'pencil', 'fell']

# %%
neighbors['banjo']
# Out:
# ['other',
#  'little',
#  'back',
#  'teacher',
#  'slidingstairsc',
#  'finish',
#  'circle',
#  'prudential',
#  'carrot']

# %%
ngram = lxa_object.word_bigram_counter()

# %%
ngram
# Out:
# {('my', 'suitcase'): 3,
#  ('toomanc', 'suitcase'): 1,
#  ('monroe', 'suitcase'): 1,
#  ('find', 'dirt'): 1,
#  ('spaghetti', 'yeah'): 1,
#  ('adam', 'glove'): 2,
#  ('put', 'ball'): 3,
#  ('put', 'the'): 2,
#  ('the', 'ball'): 2,
#  ('tape', 'recorder'): 11,
#  ('ball', 'over'): 1,
#  ('over', 'here'): 1,
#  ('hit', 'mommy'): 3,
#  ('mommy', 'wall'): 1,
#  ('mommy', 'rug'): 1,
#  ('where', 'ball'): 5,
#  ('ball', 'go'): 3,
#  ('in', 'there'): 11,
#  ('adam', 'go'): 3,
#  ('go', 'get'): 7,
#  ('get', 'it'): 10,
#  ('get', 'stuck'): 2,
#  ('adam', 'get'): 4,
#  ('bye', 'see'): 1,
#  ('see', 'later'): 1,
#  ('later', 'again'): 1,
#  ('adam', 'ball'): 2,
#  ('who', 'dat'): 56,
#  ('dat', 'that'): 107,
#  ('tootooo', 'train'): 1,
#  ('train', 'track'): 10,
#  ('read', 'dat'): 10,
#  ('that', 'train'): 1,
#  ('train', 'train'): 2,
#  ('adam', 'sit'): 10,
#  ('sit', 'down'): 11,
#  ('down', 'book'): 1,
#  ('choochoo', 'train'): 5,
#  ('diesel', 'motor'): 1,
#  ('motor', 'no'): 1,
# ...

# %%
import os

# %%
filenames = os.listdir()

# %%
filenames = sorted(filenames)

# %%
filenames
# Out:
# ['eve01.cha',
#  'eve01_words.txt',
#  'eve02.cha',
#  'eve03.cha',
#  'eve04.cha',
#  'eve05.cha',
#  'eve06.cha',
#  'eve07.cha',
#  'eve08.cha',
#  'eve09.cha',
#  'eve10.cha',
#  'eve11.cha',
#  'eve12.cha',
#  'eve13.cha',
#  'eve14.cha',
#  'eve15.cha',
#  'eve16.cha',
#  'eve17.cha',
#  'eve18.cha',
#  'eve19.cha',
#  'eve20.cha']
