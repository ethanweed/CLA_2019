# %%
pathin = '/Users/ethan/Documents/GitHub/CLA_2019/Coding/Friday Exercises/Data/NewmanRatner/07/'
file = '4687NH.cha'

# %%
import os
from string import punctuation as p


os.chdir(pathin)

removelist = ['\t', '\r']

with open(file,'r') as f:
    text = f.read()

text = [line.replace('\t:', '') for line in text]
text = [line.replace('\r:', '') for line in text]
# Out:
# @UTF8
# @PID:	11312/c-00043106-1
# @Begin
# @Languages:	eng
# @Participants:	CHI Target_Child, MOT NH7 Mother, EXP Clinician
# 	Investigator
# @Options:	bullets, notarget
# @ID:	eng|NewmanRatner|MOT||female|||Mother|||
# @ID:	eng|NewmanRatner|EXP|||||Investigator|||
# @ID:	eng|NewmanRatner|CHI|0;07.||||Target_Child|||
# @Media:	4687NH, audio
# @Transcriber:	Kerry_McColgan
# *MOT:	yummy want some more food ? 1_2044
# %mor:	adj|yum&dn-Y v|want qn|some qn|more n|food ?
# %gra:	1|2|SUBJ 2|0|ROOT 3|5|QUANT 4|5|QUANT 5|2|OBJ 6|2|PUNCT
# *CHI:	0 .
# *MOT:	how_(a)bout peas ? 2044_4572
# %mor:	pro:int|how_about n|pea-PL ?
# %gra:	1|2|MOD 2|0|INCROOT 3|2|PUNCT
# *MOT:	do you like peas ? 4420_6660
# %mor:	mod|do pro:per|you co|like n|pea-PL ?
# %gra:	1|4|AUX 2|4|SUBJ 3|4|COM 4|0|INCROOT 5|4|PUNCT
# *MOT:	yummy peas . 6660_9781
# %mor:	adj|yum&dn-Y n|pea-PL .
# %gra:	1|2|MOD 2|0|INCROOT 3|2|PUNCT
# *MOT:	let's give peas to the doggy . 9781_11940
# %mor:	v|let~pro:obj|us v|give n|pea-PL prep|to det:art|the adj|dog&dn-Y .
# %gra:	1|0|ROOT 2|3|SUBJ 3|1|COMP 4|3|OBJ 5|3|JCT 6|7|DET 7|5|POBJ 8|1|PUNCT
# *MOT:	here let's give peas to this (.) kangaroo . 11940_15988
# %mor:	adv|here v|let~pro:obj|us v|give n|pea-PL prep|to det:dem|this
# 	n|kangaroo .
# %gra:	1|2|JCT 2|0|ROOT 3|2|OBJ 4|2|COMP 5|4|OBJ 6|5|NJCT 7|8|DET 8|6|POBJ
# 	9|2|PUNCT
# *MOT:	can I have some juice or some peas ? 18080_22288
# %mor:	mod|can pro:sub|I v|have qn|some n|juice coord|or qn|some n|pea-PL
# 	?
# %gra:	1|3|AUX 2|3|SUBJ 3|0|ROOT 4|5|QUANT 5|3|OBJ 6|5|CONJ 7|8|QUANT
# 	8|6|COORD 9|3|PUNCT
# *MOT:	yum . 22288_26049
# %mor:	n|yum .
# %gra:	1|0|INCROOT 2|1|PUNCT
# *MOT:	yum yum yum yum yum yum . 25011_27619
# %mor:	n|yum n|yum n|yum n|yum n|yum n|yum .
# %gra:	1|6|MOD 2|6|MOD 3|6|MOD 4|6|MOD 5|6|MOD 6|0|INCROOT 7|6|PUNCT
# *MOT:	where's a spoon ? 40995_44211
# %mor:	pro:int|where~cop|be&3S det:art|a n|spoon ?
# %gra:	1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|PRED 5|2|PUNCT
# *MOT:	here's some baby food . 48739_50611
# %mor:	pro:exist|here~cop|be&3S qn|some n|baby n|food .
# %gra:	1|2|SUBJ 2|0|ROOT 3|5|QUANT 4|5|MOD 5|2|PRED 6|2|PUNCT
# *MOT:	look . 50611_52884
# %mor:	co|look .
# %gra:	1|0|INCROOT 2|1|PUNCT
# *MOT:	yum yum yum yum . 52884_54292
# %mor:	n|yum n|yum n|yum n|yum .
# %gra:	1|4|MOD 2|4|MOD 3|4|MOD 4|0|INCROOT 5|4|PUNCT
# *MOT:	let's feed the froggy . 54292_56387
# %mor:	v|let~pro:obj|us v|feed det:art|the adj|frog&dn-Y .
# %gra:	1|0|ROOT 2|1|OBJ 3|1|COMP 4|5|DET 5|3|OBJ 6|1|PUNCT
# *MOT:	yummy yummy . 56387_61748
# %mor:	adj|yum&dn-Y adj|yum&dn-Y .
# %gra:	1|2|MOD 2|0|INCROOT 3|2|PUNCT
# *MOT:	wanna feed him ? 61748_63732
# %mor:	v|want~inf|to v|feed pro:obj|him ?
# %gra:	1|0|ROOT 2|3|INF 3|1|COMP 4|3|OBJ 5|1|PUNCT
# *MOT:	no ? 63732_69315
# %mor:	co|no ?
# %gra:	1|0|INCROOT 2|1|PUNCT
# *MOT:	you wanna suck it ? 69315_72564
# %mor:	pro:per|you v|want~inf|to v|suck pro:per|it ?
# %gra:	1|2|SUBJ 2|0|ROOT 3|4|INF 4|2|COMP 5|4|OBJ 6|2|PUNCT
# *MOT:	oh you're gonna <f> [//] eat some food ? 72564_75555
# %mor:	co|oh pro:per|you~aux|be&PRES part|go-PRESP~inf|to v|eat qn|some
# 	n|food ?
# %gra:	1|4|COM 2|4|SUBJ 3|4|AUX 4|0|ROOT 5|6|INF 6|4|COMP 7|8|QUANT 8|6|OBJ
# 	9|4|PUNCT
# *MOT:	<we'll give the> [//] look here's the baby . 75555_79204
# %mor:	co|look pro:exist|here~cop|be&3S det:art|the n|baby .
# %gra:	1|3|COM 2|3|SUBJ 3|0|ROOT 4|5|DET 5|3|PRED 6|3|PUNCT
# *MOT:	wanna give the baby some food ? 79204_87508
# %mor:	v|want~inf|to v|give det:art|the n|baby qn|some n|food ?
# %gra:	1|0|ROOT 2|3|INF 3|1|COMP 4|5|DET 5|3|OBJ 6|7|QUANT 7|5|ENUM 8|1|PUNCT
# *MOT:	say hi . 87508_90435
# %mor:	co|say co|hi .
# %gra:	1|2|COM 2|0|INCROOT 3|2|PUNCT
# *MOT:	hi baby wanna give her some food ? 90435_93716
# %mor:	co|hi n|baby v|want~inf|to v|give pro:obj|her qn|some n|food ?
# %gra:	1|3|COM 2|3|SUBJ 3|0|ROOT 4|5|INF 5|3|COMP 6|5|OBJ2 7|8|QUANT 8|5|OBJ
# 	9|3|PUNCT
# *MOT:	slurp yum slurp yum . 93716_102531
# %mor:	v|slurp n|yum v|slurp n|yum .
# %gra:	1|0|ROOT 2|3|SUBJ 3|1|COMP 4|3|OBJ 5|1|PUNCT
# *MOT:	slurp yummy . 102531_107844
# %mor:	v|slurp adj|yum&dn-Y .
# %gra:	1|0|ROOT 2|1|JCT 3|1|PUNCT
# *MOT:	wanna give her some juice ? 107844_112867
# %mor:	v|want~inf|to v|give pro:obj|her qn|some n|juice ?
# %gra:	1|0|ROOT 2|3|INF 3|1|COMP 4|3|OBJ2 5|6|QUANT 6|3|OBJ 7|1|PUNCT
# *MOT:	wanna give the baby some juice ? 112867_115203
# %mor:	v|want~inf|to v|give det:art|the n|baby qn|some n|juice ?
# %gra:	1|0|ROOT 2|3|INF 3|1|COMP 4|5|DET 5|3|OBJ 6|7|QUANT 7|5|ENUM 8|1|PUNCT
# *MOT:	what are you looking for ? 123823_127134
# %mor:	pro:int|what aux|be&PRES pro:per|you part|look-PRESP prep|for ?
# %gra:	1|4|LINK 2|4|AUX 3|4|SUBJ 4|0|ROOT 5|4|JCT 6|4|PUNCT
# *MOT:	let's see . 127134_129359
# %mor:	v|let~pro:obj|us v|see .
# %gra:	1|0|ROOT 2|1|OBJ 3|1|COMP 4|1|PUNCT
# *MOT:	here baby you sit here . 129359_132543
# %mor:	adv|here v|baby pro:per|you v|sit adv|here .
# %gra:	1|2|JCT 2|0|ROOT 3|4|SUBJ 4|2|COMP 5|4|JCT 6|2|PUNCT
# *MOT:	oh look here's the baby's shoe . 132543_136895
# %mor:	co|oh co|look pro:exist|here~cop|be&3S det:art|the adj|baby&dn-POSS
# 	n|shoe .
# %gra:	1|4|COM 2|4|COM 3|4|SUBJ 4|0|ROOT 5|7|DET 6|7|MOD 7|4|PRED 8|4|PUNCT
# *MOT:	look at the baby's little shoe . 136895_139342
# %mor:	v|look prep|at det:art|the adj|baby&dn-POSS adj|little n|shoe .
# %gra:	1|0|ROOT 2|1|JCT 3|6|DET 4|6|MOD 5|6|MOD 6|2|POBJ 7|1|PUNCT
# *MOT:	it goes on her foot . 139342_141663
# %mor:	pro:per|it v|go-3S prep|on det:poss|her n|foot .
# %gra:	1|2|SUBJ 2|0|ROOT 3|2|JCT 4|5|DET 5|3|POBJ 6|2|PUNCT
# *MOT:	should we put her shoe on ? 141663_143999
# %mor:	mod|should pro:sub|we v|put&ZERO pro:obj|her n|shoe adv|on ?
# %gra:	1|3|AUX 2|3|SUBJ 3|0|ROOT 4|5|SUBJ 5|3|COMP 6|5|JCT 7|3|PUNCT
# *MOT:	here we go shoe . 143999_147103
# %mor:	adv|here pro:sub|we v|go n|shoe .
# %gra:	1|3|JCT 2|3|SUBJ 3|0|ROOT 4|3|OBJ 5|3|PUNCT
# *MOT:	should we read a book now ? 151962_155194
# %mor:	mod|should pro:sub|we v|read&ZERO det:art|a n|book adv|now ?
# %gra:	1|3|AUX 2|3|SUBJ 3|0|ROOT 4|5|DET 5|3|OBJ 6|3|JCT 7|3|PUNCT
# *MOT:	come here sit with mamma . 155194_158123
# %mor:	v|come adv|here v|sit prep|with n|mamma .
# %gra:	1|0|ROOT 2|3|JCT 3|1|COMP 4|3|JCT 5|4|POBJ 6|1|PUNCT
# *MOT:	mamma sheep bah . 170403_175876
# %mor:	n|mamma n|sheep co|bah .
# %gra:	1|2|MOD 2|0|INCROOT 3|2|COM 4|2|PUNCT
# *MOT:	bah xxx . 175876_177971
# %mor:	co|bah .
# %gra:	1|0|INCROOT 2|1|PUNCT
# *MOT:	xxx xxx xxx . 177971_189647
# *MOT:	want the ice cream ? 196079_197839
# %mor:	v|want det:art|the n|ice n|cream ?
# %gra:	1|0|ROOT 2|4|DET 3|4|MOD 4|1|OBJ 5|1|PUNCT
# *MOT:	they're gonna hafta clean off all their toys . 203374_208031
# %mor:	pro:sub|they~aux|be&PRES part|go-PRESP~inf|to mod|have~inf|to
# 	v|clean prep|off qn|all det:poss|their n|toy-PL .
# %gra:	1|3|SUBJ 2|3|AUX 3|0|ROOT 4|7|INF 5|7|AUX 6|7|INF 7|3|COMP 8|7|JCT
# 	9|11|QUANT 10|11|DET 11|8|POBJ 12|3|PUNCT
# *MOT:	look . 211323_214284
# %mor:	co|look .
# %gra:	1|0|INCROOT 2|1|PUNCT
# *MOT:	it's spoons . 214284_217227
# %mor:	pro:per|it~cop|be&3S n|spoon-PL .
# %gra:	1|2|SUBJ 2|0|ROOT 3|2|PRED 4|2|PUNCT
# *MOT:	spoons . 217227_220331
# %mor:	n|spoon-PL .
# %gra:	1|0|INCROOT 2|1|PUNCT
# *MOT:	is that yummy ? 223419_226811
# %mor:	cop|be&3S det:dem|that adj|yum&dn-Y ?
# %gra:	1|0|ROOT 2|3|DET 3|1|PRED 4|1|PUNCT
# *MOT:	let's keep it out of the box . 226811_231659
# %mor:	v|let~pro:obj|us v|keep pro:per|it adv|out prep|of det:art|the
# 	n|box .
# %gra:	1|0|ROOT 2|1|OBJ 3|1|COMP 4|3|OBJ 5|3|JCT 6|5|JCT 7|8|DET 8|6|POBJ
# 	9|1|PUNCT
# *MOT:	so we know what they hafta wash . 231659_234455
# %mor:	co|so pro:sub|we v|know pro:int|what pro:sub|they mod|have~inf|to
# 	v|wash .
# %gra:	1|3|COM 2|3|SUBJ 3|0|ROOT 4|8|LINK 5|8|SUBJ 6|8|AUX 7|8|INF 8|3|COMP
# 	9|3|PUNCT
# *MOT:	what do you see ? 239287_241383
# %mor:	pro:int|what mod|do pro:per|you v|see ?
# %gra:	1|4|OBJ 2|4|AUX 3|4|SUBJ 4|0|ROOT 5|4|PUNCT
# *MOT:	what do you see ? 241383_243975
# %mor:	pro:int|what mod|do pro:per|you v|see ?
# %gra:	1|4|OBJ 2|4|AUX 3|4|SUBJ 4|0|ROOT 5|4|PUNCT
# *MOT:	here are the spoons . 252835_253870
# %mor:	adv|here cop|be&PRES det:art|the n|spoon-PL .
# %gra:	1|2|JCT 2|0|ROOT 3|4|DET 4|2|PRED 5|2|PUNCT
# *MOT:	here are keys . 253870_254735
# %mor:	adv|here cop|be&PRES n|key-PL .
# %gra:	1|2|JCT 2|0|ROOT 3|2|PRED 4|2|PUNCT
# *MOT:	here's a bottle . 259315_260835
# %mor:	pro:exist|here~cop|be&3S det:art|a n|bottle .
# %gra:	1|2|SUBJ 2|0|ROOT 3|4|DET 4|2|PRED 5|2|PUNCT
# *MOT:	don't know what that is . 260835_263570
# %mor:	mod|do~neg|not v|know pro:int|what adv|that cop|be&3S .
# %gra:	1|3|AUX 2|1|NEG 3|0|ROOT 4|6|LINK 5|6|JCT 6|3|COMP 7|3|PUNCT
# *MOT:	don't fall . 296335_298271
# %mor:	mod|do~neg|not v|fall .
# %gra:	1|3|AUX 2|1|NEG 3|0|ROOT 4|3|PUNCT
# @End

# %%
for line in text:
    if line.startswith('Participants: '):
        p = line.replace('Participants: ', '')
        p = p.split(',')

    p1 = []
    for i, val in enumerate(p):
        v1 = val.replace(' ','')
        v2 = v1.replace('\n', '')
        p1.append(v2[0:3])
    people = p1

with open(file,'r') as f:
    text = f.read()
    for item in removelist:
        text = text.replace(item, '')
        text = text.split('\n')

    trans = []
    for line in text:
        label = line[1:4]
        if label in people:
            trans.append(line)
        elif label == 'mor':
            trans.append(line)

grouped = [trans[n:n+2] for n in range(0, len(trans), 2)]
#print(grouped)

p = '.!?'

turn = []
speaker = []
mor = []
for i, val in enumerate(grouped):
    turn.append(i+1)

for i in grouped:
    s = i[0]
    m = i[1]
    for c in p:
        m = m.replace(c, '')
        m = m.strip()
        m = m.replace('%mor:', '')
        speaker.append(s[1:4])
        mor.append(m)

z = list(zip(turn, speaker, mor))

turn = []
speaker = []
pss = []
wds = []
for i, val in enumerate(z):
    x = z[i]
    t = x[0]
    s = x[1]
    m = x[2]
    m = m.split(' ')
    p = []
    w = []
    for n in m:
        temp = n.split('|')
        p.append(temp[0])
        w.append(temp[1])
    turn.append(t)
    speaker.append(s)
    pss.append(p)
    wds.append(w) 

pw = list(zip(turn,speaker,pss,wds))
print(pw)

lines = []
for i in pw:
    num = str(i[0])
    speaker = i[1]
    wds = i[3]
    pss = i[2]
    for j, val in enumerate(pss):
        p = pss[j]
        w = wds[j]
        temp = num + ',' + speaker + ',' + w + ',' + p + '\n'
        lines.append(temp)      

header = 'Turn,' + 'Speaker,' + 'Word' + 'POS' + '\n'
data = ''.join(lines)
output = header + data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-4f1dccf32a2f> in <module>()
#      30     text = f.read()
#      31     for item in removelist:
# ---> 32         text = text.replace(item, '')
#      33         text = text.split('\n')
#      34
#
# AttributeError: 'list' object has no attribute 'replace'
